# %% [markdown]
# **Code block to parse the pdf file and break the text into smaller chunks**

# %%
from tika import parser  
from text_splitter import RecursiveCharacterTextSplitter


# opening pdf file
parsed_pdf = parser.from_file("C:\\Users\\nqazi\\Downloads\\EmployeeHandbook.pdf")

# parsed_pdf['content'] returns string 
data = parsed_pdf['content'] 

splitter = RecursiveCharacterTextSplitter()
paragraphs = splitter.split_text(text=data)

def clean_text(text):
    cleaned_string = text.replace("\n","").replace('..',"")
    return cleaned_string
cleaned_paragraphs = [clean_text(para) for para in paragraphs]
# Out:
# 2023-03-06 19:17:04,938 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# 2023-03-06 19:17:09,950 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...

# %% [markdown]
# **Generate embeddings and index using Faiss for searching <br>
# d --> vector dimension<br>
# k --> neighbours**<br>

# %%
from sentence_transformers import SentenceTransformer,util
import faiss

#Initializing the model
model = SentenceTransformer('msmarco-distilbert-base-v4')
#Passing text chunks to the model to generate embeddings(No. of chunks = 28)
para_embeddings = model.encode(cleaned_paragraphs)
print(f"para_embed: {para_embeddings.shape}")
d = 768
k = 10
index = faiss.IndexFlatIP(d)
index.add(para_embeddings)
# Out:
# para_embed: (28, 768)

# %% [markdown]
# **Method to calculate the number of tokens**

# %%
def num_tokens_from_string(string, encoding_name):
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %% [markdown]
# **Initializing OpenAPI's secret key and models<br>
# model_vector --> used to generate embeddings<br>
# model_encode --> used for ranking**<br>

# %%
import numpy as np
from sentence_transformers import SentenceTransformer,CrossEncoder,util
import tiktoken
import openai

openai.api_key = "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"

#initialize models
# Model 1: msmarco-distilbert-base-v4 
# Model 2: all-MiniLM-L6-v2
model_vector = SentenceTransformer('msmarco-distilbert-base-v4')

# Model 1: cross-encoder/stsb-roberta-large
# Model 2: cross-encoder/ms-marco-MiniLM-L-12-v2
model_encoder = CrossEncoder("cross-encoder/stsb-roberta-large")

# %% [markdown]
# **Step 1: Get query text<br>
# Step 2: Convert the query text to vector<br>
# Step 3: Perform a search using faiss to get top 10 relevant paragraphs<br>
# Step 4: Rank the relevant paragraphs using cross encoder<br>
# Step 5: Use top 3 relevant paragraphs to build a refined prompt with context<br>
# Step 6: Feed the query along with the context to text-davinci-003<br>**

# %%
while True:
    #get query
    query = input("How can I assist you? ")
    
    if not query:
        break
        
    #create query vector and fetch relevant indexes
    query_vector = model_vector.encode([query])
    print(f"type: {type(query_vector)}")
    print(f"shape: {query_vector.shape}")
    D,I = index.search(query_vector, k)
    relevant_indexes = I.tolist()[0]

    # using indexes get relevant paragraphs
    relevant_paras = []
    for i in relevant_indexes:
        relevant_paras.append(cleaned_paragraphs[i])

    #create query-paragraph pairs and calculate similarity scores to rank paragraphs
    query_paras_combined = [[query, para] for para in relevant_paras]
    similarity_scores = model_encoder.predict(query_paras_combined)
    sim_scores_argsort = list(reversed(np.argsort(similarity_scores)))
    
    
    print(f"similarity score: {similarity_scores}")
    for idx in sim_scores_argsort:
        print("{:.2f}\t{}".format(similarity_scores[idx], relevant_paras[idx]))
        print(idx)
        print('********************************************')
    #sort indexes based on scores
    

    #build context -- max paragraphs allowed in context is set to 3 and max token length is set to 2700
    relevant_context = ""
    threshold = 3       
    for idx in sim_scores_argsort:
        if threshold > 0 and num_tokens_from_string(relevant_context, "p50k_base")+num_tokens_from_string(relevant_paras[idx], "p50k_base")<2700:
            relevant_context += relevant_paras[idx] + "\n\n"
            threshold = threshold - 1
        else:
            break

    #generate an input prompt
    refined_prompt = f"""
    Answer the question based on the contexts below. 
    If the question cannot be answered using the information 
    provided answer with "I don't know".

    ###

    Contexts:
    {relevant_context}

    ###

    Question:{query}
    Answer:"""
    #print(f"""Tokens in the prompt: {num_tokens_from_string(refined_prompt, "p50k_base")}""")
    print(f"Refined Prompt: {refined_prompt}")

    #Feed input prompt to openai model
    response = openai.Completion.create(
    engine="text-davinci-003",
    prompt=refined_prompt,
    temperature=0.0,
    max_tokens=1024,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
    )

    #print response from openai model
    print(f"""Answer from text-davinci-003: {response["choices"][0]["text"]}""")
# Out:
# How can I assist you? variable bonus
# type: <class 'numpy.ndarray'>
# shape: (1, 768)
# similarity score: [0.47829464 0.5164373  0.5297895  0.61881393 0.22020826 0.59888375
#  0.51692873 0.63073874 0.55351055 0.5018603 ]
# ...

# %% [markdown]
# **Sample Questions

# %%
# I would like to know about variable bonus
# what are the types of leaves available along with the leave counts
# what is the work from home policy
# I want to change my track from QA Automation to SDET, can I know the process for it?
# Can you please tell me where to find the loan application form?
#I wanted to know if there is any specific category of leaves that I can apply for marriage
# How to apply for Paternity Leaves?
#I want to change or update my address/mail address/phone number.

# %%
#from langchain.document_loaders import UnstructuredDocxLoader, UnstructuredPDFLoader
from langchain.text_splitter import SpacyTextSplitter

# %%
from langchain.docstore.document import Document

# %%
#loader = UnstructuredDocxLoader('C:\\Users\\nqazi\\Downloads\\Tracking&TradingGuide.docx')
#loader = UnstructuredPDFLoader('C:\\Users\\nqazi\\Downloads\\Benefits.pdf')

# %%
from tika import parser  

# opening pdf file
parsed_pdf = parser.from_file("C:\\Users\\nqazi\\Downloads\\Benefits.pdf")

# parsed_pdf['content'] returns string 
data = parsed_pdf['content']

# %%
#data = loader.load()
data = [Document(page_content=data)]

# %%
text_splitter = SpacyTextSplitter(chunk_size = 1200, chunk_overlap=200)

# %%
texts = text_splitter.split_documents(data)

# %%
len(texts)
# Out:
# 70

# %%
type(texts[0])
# Out:
# langchain.docstore.document.Document

# %%
from langchain.embeddings import OpenAIEmbeddings

# %%
import openai
openai.api_key = "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"
COMPLETIONS_MODEL = "text-davinci-003"
EMBEDDING_MODEL = "text-embedding-ada-002"

# %%
def get_embedding(text):
    import time
    result = openai.Embedding.create(
      model=EMBEDDING_MODEL,
      input=text
    )
    time.sleep(2)
    return result["data"][0]["embedding"]

# %%
embeddings = [get_embedding(para.page_content) for para in texts]

# %%
import numpy
X = numpy.array(embeddings)

# %%
X.shape
# Out:
# (70, 1536)

# %%
import faiss
d = len(embeddings[0])
k = 10
index = faiss.IndexFlatIP(d)
index.add(X)

# %%
def num_tokens_from_string(string, encoding_name):
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %%
import numpy as np
from sentence_transformers import CrossEncoder
import tiktoken

# Model 1: cross-encoder/stsb-roberta-large
# Model 2: cross-encoder/ms-marco-MiniLM-L-12-v2
model_encoder = CrossEncoder("cross-encoder/stsb-roberta-large")

# %%
def openai_chat_completion(openai_params):
    import openai
    completion = None
    logs = None
    completion = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "user", "content": openai_params.get("prompt")}
        ],
        max_tokens=openai_params.get("max_tokens"),
        temperature=openai_params.get("temperature"),
        # stop=openai_params.get("stop")
    )
    return {
        "response": completion.choices[0].message.content,
        "input_tokens": completion.usage.prompt_tokens,
        "output_tokens": completion.usage.get("completion_tokens", 0),
    }

# %%
while True:
    #get query
    query = input("How can I assist you? \n")
    
    if not query:
        break
        
    #create query vector and fetch relevant indexes
    query_vector = numpy.array([get_embedding(query)])
    print(f"query vector type: {type(query_vector)}")
    print(f"query vector dimensions: {query_vector.shape}")
    D,I = index.search(query_vector, k)
    relevant_indexes = I.tolist()[0]

    # using indexes get relevant paragraphs
    relevant_paras = []
    for i in relevant_indexes:
        relevant_paras.append(texts[i].page_content)

    #create query-paragraph pairs and calculate similarity scores to rank paragraphs
    query_paras_combined = [[query, para] for para in relevant_paras]
    similarity_scores = model_encoder.predict(query_paras_combined)
    sim_scores_argsort = list(reversed(np.argsort(similarity_scores)))
    
    
    print(f"similarity score: {similarity_scores}")
    for idx in sim_scores_argsort:
        print("{:.2f}\t{}".format(similarity_scores[idx], relevant_paras[idx]))
        print(idx)
        print('********************************************')
    #sort indexes based on scores
    

    #build context -- max paragraphs allowed in context is set to 3 and max token length is set to 2700
    relevant_context = ""
    threshold = 3       
    for idx in sim_scores_argsort:
        if threshold > 0 and num_tokens_from_string(relevant_context, "p50k_base")+num_tokens_from_string(relevant_paras[idx], "p50k_base")<2700:
            relevant_context += relevant_paras[idx] + "\n\n"
            threshold = threshold - 1
        else:
            break

    #generate an input prompt
    refined_prompt = f"""
    You are the HR of a company and you need to answer the question based on the contexts below. 
    If the question cannot be answered using the information 
    provided answer with "I don't know".

    ###

    Contexts:
    {relevant_context}

    ###

    Question:{query}
    Answer:"""
    #print(f"""Tokens in the prompt: {num_tokens_from_string(refined_prompt, "p50k_base")}""")
    print(f"Refined Prompt: {refined_prompt}")

    #Feed input prompt to openai model
    openai_params = {"temperature": 0.3, "max_tokens":1024, "prompt": refined_prompt}
    response = openai_chat_completion(openai_params)

    #print response from openai model
    print(f"""Answer from gpt-3.5-turbo: {response}""")
# Out:
# How can I assist you?
# How can I avail the well being subsidy?
# query vector type: <class 'numpy.ndarray'>
# query vector dimensions: (1, 1536)
# similarity score: [0.3364833  0.47716084 0.39226437 0.46028483 0.51911324 0.43687564
#  0.39603576 0.53515893 0.2612432  0.43206078]
# 0.54	All qualifying expenses incurred in a fiscal year can be reimbursed providing it does not
# exceed the maximum allowable reimbursement of INR 25,000.
#
# New hires can claim
#
# reimbursement for expenses incurred post their effective date of joining.
#
#
#
# 3.
#
# Since the program will launch in January 2022 (mid-FY22), am I eligible
# for the full annual Subsidy of INR 25,000?
#
#
#
# Yes, professionals can avail the Well-being Subsidy up to a maximum of INR 25,000
# every fiscal year.
#
# With the program launch on January 1, 2022 (middle of FY22),
#
# professionals can claim the full Subsidy (up to INR 25,000) for qualifying expense(s)
# incurred from January 1, 2022 through May 28, 2022.
#
# ...

# %%
query = "wziard tool"
query_vector_list = get_embedding(query)
query_vector = numpy.array([query_vector_list])

# %%
query_vector.shape
# Out:
# (1, 1536)

# %%
len(query_vector_list)
# Out:
# 1536

# %%
np.array(query).reshape(-1,1536).shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23964\882379279.py in <cell line: 1>()
# ----> 1 np.array(query).reshape(-1,1536).shape
#
# ValueError: cannot reshape array of size 1 into shape (1536)

# %%
def get_embedding(text, mode='online'):
    if mode == 'online':
        import time
        import openai
        EMBEDDING_MODEL = "text-embedding-ada-002"
        result = openai.Embedding.create(
            model=EMBEDDING_MODEL,
            input=text
        )
        time.sleep(2)
        text_vector = result["data"][0]["embedding"]
        return text_vector
    else:
        from sentence_transformers import SentenceTransformer
        # Model 1: msmarco-distilbert-base-v4 
        # Model 2: all-MiniLM-L6-v2
        model_vector = SentenceTransformer('msmarco-distilbert-base-v4')
        return model_vector.encode(text)


def get_embeddings(texts, mode='online'):
    if mode == 'online':
        import numpy
        embeddings = [get_embedding(text.page_content) for text in texts]
        embeddings = numpy.array(embeddings)
    else:
        from sentence_transformers import SentenceTransformer
        # Model 1: msmarco-distilbert-base-v4 
        # Model 2: all-MiniLM-L6-v2
        model_vector = SentenceTransformer('msmarco-distilbert-base-v4')
        chunks = [text.page_content for text in texts]
        embeddings = model_vector.encode(chunks)
    return embeddings


def num_tokens_from_string(string, encoding_name):
    """Returns the number of tokens in a text string."""
    import tiktoken
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens


def rank_texts(relevant_texts, query, threshold=3, max_tokens=2700):
    from sentence_transformers import CrossEncoder
    import numpy as np
    # Model 1: cross-encoder/stsb-roberta-large
    # Model 2: cross-encoder/ms-marco-MiniLM-L-12-v2
    model_encoder = CrossEncoder("cross-encoder/stsb-roberta-large")
    relevant_context = ""
    query_paras_combined = [[query, para] for para in relevant_texts]
    similarity_scores = model_encoder.predict(query_paras_combined)
    sim_scores_argsort = list(reversed(np.argsort(similarity_scores)))
    for idx in sim_scores_argsort:
        print("{:.2f}\t{}".format(similarity_scores[idx], relevant_texts[idx]))

        print('\n********************************************\n\n')
        if threshold > 0 and num_tokens_from_string(relevant_context, "p50k_base") + num_tokens_from_string(
                relevant_texts[idx], "p50k_base") < max_tokens:
            relevant_context += relevant_texts[idx] + "\n\n"
            threshold = threshold - 1
        else:
            break
    return relevant_context


def get_prompt(relevant_context, query):
    prompt = f"""
    You are the HR of a company and you need to answer the question based on the contexts below. 
    If the question cannot be answered using the information 
    provided answer with "I don't know".

    ###

    Contexts:
    {relevant_context}

    ###

    Question:{query}
    Answer:"""
    return prompt


def parse_document(path):
    from tika import parser
    from langchain.docstore.document import Document

    # opening pdf file
    parsed_pdf = parser.from_file(path)

    # parsed_pdf['content'] returns string 
    data = parsed_pdf['content']
    data = [Document(page_content=data)]

    return data


def split_text(text, chunk_size=1200, chunk_overlap=200):
    from langchain.text_splitter import SpacyTextSplitter
    text_splitter = SpacyTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
    text_chunks = text_splitter.split_documents(text)
    return text_chunks


def index_embeddings(embeddings):
    import faiss
    d = embeddings.shape[1]
    index = faiss.IndexFlatIP(d)
    index.add(embeddings)
    return index


def openai_chat_completion(openai_params):
    import openai
    completion = None
    completion = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "user", "content": openai_params.get("prompt")}
        ],
        max_tokens=openai_params.get("max_tokens"),
        temperature=openai_params.get("temperature"),
        # stop=openai_params.get("stop")
    )
    return {
        "response": completion.choices[0].message.content,
        "input_tokens": completion.usage.prompt_tokens,
        "output_tokens": completion.usage.get("completion_tokens", 0),
    }

# %%
"""
Sample script for using OpenAI utils
"""

# from .service import parse_document, split_text, get_embeddings, \
# index_embeddings, rank_texts, get_prompt, openai_chat_completion, get_embedding
import numpy

def get_answers(query):
    #converting the pdf file to text
    data = parse_document(path = 'C:\\Users\\nqazi\\Downloads\\Benefits.pdf')

    #splitting text into smaller chunks
    text_chunks = split_text(data)

    #get embeddings in online/offline mode
    embeddings = get_embeddings(text_chunks, mode='online')
    embeddings_offline = get_embeddings(text_chunks, mode='offline')

    #creating indexes for embeddings
    index = index_embeddings(embeddings)
    index_offline = index_embeddings(embeddings_offline)

    #creating a vector from query
    query_vector = numpy.array([get_embedding(query, mode='online')])
    
    k=10 #Nearest Neighbours

    #Searching for relevant chunks and fetching the indexes
    D,I = index.search(query_vector, k)
    relevant_indexes = I.tolist()[0]

    #fetching the relevant chunks
    relevant_chunks = []
    for i in relevant_indexes:
        relevant_chunks.append(text_chunks[i].page_content)

    #ranking the chunks based on the query
    context = rank_texts(relevant_chunks, query)

    #creating relevant prompt
    relevant_context = get_prompt(context, query)

    openai_params = {
                        "prompt": relevant_context, 
                        "max_tokens":1024, 
                        "temperature":0.1
                    }

    #return the openai response
    return openai_chat_completion(openai_params)

# %%
import openai
openai.api_key = "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"

get_answers("what is the hybrid allowance?")
# Out:
# 0.58	A:
#
# Yes, the program offers a total allowance of up to INR 15,000 towards one or a
#
# combination of qualifying technology purchases.
#
#
#
#
#
# Q: What period does this program cover?
#
#
#
# A: The program is effective for the period September 28, 2021 through May 28, 2022,
#
# offering eligible participants reimbursement on 100% of the cost of qualifying technology
#
# items with a purchase date between September 28, 2021 and May 28, 2022 up to a total
#
# of INR 15,000.
#
# Reimbursement of these expenses reflect an interim FY22 decision and
#
# will be re-evaluated annually.
#
#
#
# Exception: The hybrid productivity allowance does NOT expire at the end of FY22 for
#
# new hires who start after May 1 and anytime in FY23.
#
# They will have all of FY23 to
#
# use their hybrid productivity allowance (note: name change for FY23 to hybrid
#
# technology allowance).
#
#
#
#
#
#
#
#
#
#
#
# 18
# HashedIn by
#
# Deloitte 2023
#
# ...

# %%
def get_answer(question,context):    
    from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline
    #distilbert-base-cased-distilled-squad
    # deepset/roberta-base-squad2
    model_name = "distilbert-base-cased-distilled-squad"

    # a) Get predictions
    nlp = pipeline('question-answering', model=model_name)# tokenizer=model_name
    QA_input = {
        'question': question,
        'context': context
    }
    res = nlp(QA_input)

#     if res['score']<0.5:
#         res['answer'] = "I don't know"
    
    return res

    # # b) Load model & tokenizer
    # model = AutoModelForQuestionAnswering.from_pretrained(model_name)
    # tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
res
# Out:
# {'score': 0.9813961386680603,
#  'start': 119,
#  'end': 138,
#  'answer': 'account and product'}

# %%
question = 'What are the potential risks and limitations of the proposed MuleSoft product and how can they be addressed?'
context = 'As a mulesoft developer I have to design an API to update both SAP and SFDC. There are 2 objects to be inserted namely account and product. All the insertions is controlled by using the query parameter setToSource & setToTarget as shown above in the table. Posting to both the systems is an invalid scenario. Along with that updating SFDC source with product data is invalid. This resource too follows client id enforcement policy for auth entication by passing client_id and client_secret in headers.  \nThe request structure is defined in the documentation shared and it follows the same transformation and response structure as mentioned above in get request.'

# %%
get_answer(question, context)
# Out:
# {'score': 0.09199026972055435,
#  'start': 454,
#  'end': 500,
#  'answer': 'passing client_id and client_secret in headers'}
